# %%
m=int(input("Enter your marks:"))
if m>90:
    print("Grade A")
elif m>80:
    print("Grade B")
elif m>70:
    print("Grade C")
elif m>60:  
    print("Grade D")
else: print("Fail")
# Out:
# Fail

# %%
l=[]
print(type(l))
# Out:
# <class 'list'>

# %%
l=[1,2,3,4,5]
print("the no's are:",l)
# Out:
# the no's are: [1, 2, 3, 4, 5]

# %%
l=[1,"K",2,"O",3,"M",4,"I",5]
print("the no's are:",l,type(l))
print(l[0:4])
# Out:
# the no's are: [1, 'K', 2, 'O', 3, 'M', 4, 'I', 5] <class 'list'>
# [1, 'K', 2, 'O']

# %%
#reverse a list 
l=[1,2,7,4,6]
for i in range(5,0,-1):
    print(l[i-1])

l1=[1,2,9,1,0,5]
l1.reverse()
print(l1)
#lenght
c= len(l1)
print(c)

for i in range(4):
    print(l[i])
print()

for x in l1:
    print(x)

#Sum of the list no
l1=[1,2,9,1,0,5]
sum=0
for i in l1:
  sum+=i
print("the sum is:",sum)

#Max
l1=[1,2,9,1,0,5]
max=l1[0]
for i in l1:
    if i>max:
        max=i
print(max)
# Out:
# 6
# 4
# 7
# 2
# 1
# [5, 0, 1, 9, 2, 1]
# 6
# 1
# 2
# 7
# 4
#
# 5
# 0
# 1
# 9
# 2
# 1
# the sum is: 18
# 9

# %%
#String Split
str="Kanishka joshi" 
k=str.split()
print(k)
# Out:
# ['Kanishka', 'joshi']

# %%
#more items can be added in the list with the help of the append , only 1 item is added at a time , more more additions , loops are being used with the append function 

l=[]
print(l)
l.append("Joshi")
l.append(45)
print(l)

#appending one list to another
l1=["Darshil","Kanishka"]
l1.append(l)
print(l1)

print(l1[2][0])

#insert
print(l1)
print(l)
l1.insert(1,l)
print(l1)

#Extend
l2=[1,2,3,4,5]
l.extend(l2)
print(l)

#remove
l2.remove(5)
print(l2)

#pop= deletes last element
l2.pop()
print(l2)
# Out:
# []
# ['Joshi', 45]
# ['Darshil', 'Kanishka', ['Joshi', 45]]
# Joshi
# ['Darshil', 'Kanishka', ['Joshi', 45]]
# ['Joshi', 45]
# ['Darshil', ['Joshi', 45], 'Kanishka', ['Joshi', 45]]
# ['Joshi', 45, 1, 2, 3, 4, 5]
# [1, 2, 3, 4]
# [1, 2, 3]

# %%
numbers=[1,2,3,4,5]
Sum=sum(numbers)
print(Sum)
Sum=sum(numbers,10)
print(Sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 numbers=[1,2,3,4,5]
# ----> 2 Sum=sum(numbers)
#       3 print(Sum)
#       4 Sum=sum(numbers,10)
#       5 print(Sum)
#
# TypeError: 'int' object is not callable

# %%
#queue.py
while(True):
    print("""
          1.Add a element
          2.Remove Element
          3.Display first three elements
          4.Display last three elements
          5.Print
          6.Exit""")
    ch = int(input("Enter your choice:"))
    if ch == 1:
        pass
    elif ch == 2:
        pass
    elif ch == 3:
        pass
    elif ch == 4:
        pass
    elif ch == 5:
        pass
    elif ch == 6:
        break
    else:
        print("Invalid choice")

# %%
#Dictionary
d={1:"python",2:"Java","Name":"C++","d2":{"dept":"IT","sec":"A"}}
print(d,type(d))

print(d["Name"])
print(d["d2"]["sec"])



dict={}
dict['Name'] ="Kanishka"
dict['Age'] = 20
dict['Dept'] = "CSE"
print(dict)
del(dict['Dept'])
print(dict)
print(dict.keys())
print(dict.values())


#Doubt ........
dict1={'Name':'Darshil','Age':21,'Dept':'IT'}
dict.update(dict1)
print(dict)
# Out:
# {1: 'python', 2: 'Java', 'Name': 'C++', 'd2': {'dept': 'IT', 'sec': 'A'}} <class 'dict'>
# C++
# A
# {'Name': 'Kanishka', 'Age': 20, 'Dept': 'CSE'}
# {'Name': 'Kanishka', 'Age': 20}
# dict_keys(['Name', 'Age'])
# dict_values(['Kanishka', 20])
# {'Name': 'Darshil', 'Age': 21, 'Dept': 'IT'}
