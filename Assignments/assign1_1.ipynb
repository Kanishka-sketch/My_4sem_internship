# %%
#) Practice print statement: - with multiple object - with seperator - with "ends"

name = "Darshil"
age = 20

print("Name:", name, "Age:", age)

#with separator.
print("2026", "06", "05", sep="-")

print("Python", "Java", "C++", sep=" | ")

#Print with the help of end.
print("Almost", end="...")
print("Done")
# Out:
# Name: Darshil Age: 20
# 2026-06-05
# Python | Java | C++
# Almost...Done

# %%
#2) Using input ask user to enter his/her name and output user name with a greeting message in python

name = input("Enter your name:")

print("Hello,", name + "!","Welcome to Python Programming.")

name = input("Enter your name: ")
print(f"Hello, {name}! Welcome to Python Programming.")
# Out:
# Hello, Kanishka! Welcome to Python Programming.
# Hello, Darshil! Welcome to Python Programming.
